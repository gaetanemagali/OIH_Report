# %%
from rdflib import Graph
from tqdm import tqdm  # Ensure you have tqdm installed for progress bar
import logging
import requests
import pandas as pd
from IPython.display import display
import random


# Configure logging
logging.basicConfig(level=logging.INFO)

# %%
#We want to use the terms we extracted from Wikipedia
terms_file = ''#file path to microbial index

with open(terms_file, 'r') as file:
    wiki_terms = file.read().splitlines() #reads content line by line and turns it into a list

# %%
def create_sparql_query(wiki_terms):
    query_terms = '|'.join(wiki_terms)
    sparql_query = f"""
    PREFIX schema: <http://schema.org/>

    SELECT ?subject ?name ?description ?keywords
    WHERE {{
        # ?subject a schema:Dataset ;
                 schema:name ?name ;
                 schema:description ?description ;
                 schema:creator ?creator;
                 schema:keywords ?keywords .
        FILTER (
            regex(?keywords, "{query_terms}", "i")
        )
    }}
    """
    return sparql_query

wiki_query = create_sparql_query(wiki_terms)

# %%
def query_odis_endpoint(wiki_query):
    endpoint_url = "http://graph.oceaninfohub.org/blazegraph/namespace/oih/sparql"
    response = requests.post(endpoint_url, data={'query': wiki_query, 'format': 'json'})
    response.raise_for_status()
    return response.json()

# Use the modified query
wiki_results = query_odis_endpoint(wiki_query)

# %%
# Step 4: Extract nodes from the JSON response
def extract_nodes(wiki_results, wiki_terms):
    nodes = []
    for result in wiki_results['results']['bindings']:
        keywords = result.get('keywords', {}).get('value', '')
        # Ensure at least one term from wiki_terms is present in the keywords
        if any(term.lower() in keywords.lower() for term in wiki_terms):
            node = {
                'subject': result['subject']['value'],
                'name': result.get('name', {}).get('value', ''),
                'description': result.get('description', {}).get('value', ''),
                'keywords': keywords
            }
            nodes.append(node)
    return nodes

# %%
# Correctly call the function with both arguments
nodes = extract_nodes(wiki_results, wiki_terms)

# %%
logging.info(f"Total nodes extracted: {len(nodes)}")
# Out:
# INFO:root:Total nodes extracted: 565676

# %%
print(nodes[:10])
# Out:
# [{'subject': 'https://catalogue.cioos.ca/dataset/ec330c0c-e6dd-42d2-8c7e-78197b3c5d11', 'name': 'Integrated resource management action plan for the bay and laval river sector', 'description': 'The purpose of this project is to promote the protection, enhancement and sustainable use of the resources of forest and aquatic wildlife habitats in the bay and Laval river areas. This approach follows the acquisition of knowledge of 13 sites of ecological interest, the results of which can be found in the Intervention guide for the protection and enhancement of coastal habitats of interest. Of all the habitats in the lower estuary, the relative ecological importance of the Laval bay area was considered to be very high. In view of the presence of several species of fish of interest in the bay and the Laval river, including salmon, sea trout and smelt, one of the most important clam production areas in Quebec, Important colonies of birds on Laval island, which has been granted wildlife sanctuary status, and a significant concentration of migratory birds. The project also aims to improve the current situation by involving local stakeholders including residents, users and resource persons from different ministries and institutions in an integrated resource management approach.\n\n__Source identification__:\n------------\n\n__Report:__\n\nUse report source identification + " Published on St. Lawrence Global Observatory-SLGO. [https://slgo.ca]. Access date: [YYYY-MM-DD]." ', 'keywords': 'production'}, {'subject': 'https://catalogue.cioos.ca/dataset/ec330c0c-e6dd-42d2-8c7e-78197b3c5d11', 'name': 'Integrated resource management action plan for the bay and laval river sector', 'description': 'The purpose of this project is to promote the protection, enhancement and sustainable use of the resources of forest and aquatic wildlife habitats in the bay and Laval river areas. This approach follows the acquisition of knowledge of 13 sites of ecological interest, the results of which can be found in the Intervention guide for the protection and enhancement of coastal habitats of interest. Of all the habitats in the lower estuary, the relative ecological importance of the Laval bay area was considered to be very high. In view of the presence of several species of fish of interest in the bay and the Laval river, including salmon, sea trout and smelt, one of the most important clam production areas in Quebec, Important colonies of birds on Laval island, which has been granted wildlife sanctuary status, and a significant concentration of migratory birds. The project also aims to improve the current situation by involving local stakeholders including residents, users and resource persons from different ministries and institutions in an integrated resource management approach.\n\n__Source identification__:\n------------\n\n__Report:__\n\nUse report source identification + " Published on St. Lawrence Global Observatory-SLGO. [https://slgo.ca]. Access date: [YYYY-MM-DD]." ', 'keywords': 'ckan'}, {'subject': 'https://catalogue.cioos.ca/dataset/7d62cd50-668a-43f5-acf9-b8725319586d', 'name': 'Characterization of important coastal habitats on the north shore of the St.Lawrence maritime Estuary : Baie de Mille-Vaches marsh', 'description': 'A project to characterize important coastal habitats on the north shore of the lower St. Lawrence estuary has been funded for a period of 4 years (2018-2022). The purpose of this project is to generate ecological reference data to draw an overall portrait of the state of six coastal marshes, namely the marshes of Portneuf-sur-Mer (https://catalogue.ogsl.ca/fr/dataset/ 5374b582-43aa-4ffa-8361-4a0d9f1f6b8e), Pointe des Fortin (https://catalogue.ogsl.ca/dataset/3b8c6d97-6eb8-4e8d-9869-ccb2b9bab5f3), Pointe-aux-Outardes (https: //catalogue.ogsl.ca/en/dataset/46d3ba2e-2fd3-4aad-a51a-f8343fbe6a73),baies des Grandes et Petites Bergeronnes (https://catalogue.ogsl.ca/dataset/ca-cioos_a5125bd3-60e3-4c89-89b6-2d3a8728d10f) and baie des Mil ...

# %%
# Randomly select 50 nodes
random_nodes = random.sample(nodes, 50)

# %%
# Ensure to randomly select 50 nodes
random_nodes = random.sample(nodes, 50)

# Convert the list of random nodes to a DataFrame
random_nodes_df = pd.DataFrame(random_nodes)

# Save the DataFrame to a CSV file
random_nodes_df.to_csv('wiki_subset_50_random.csv', index=False)

# Print the DataFrame of 50 random nodes to confirm
print(random_nodes_df)
# Out:
#                                               subject  \
# 0   https://catalogue.cioos.ca/dataset/06281b0d-52...
# 1   https://catalogue.cioos.ca/dataset/ad06f0b9-0e...
# 2   https://catalogue.cioos.ca/dataset/ca-cioos_79...
# 3   https://catalogue.cioos.ca/dataset/ca-cioos_9c...
# 4   https://catalogue.cioos.ca/dataset/ca-cioos_c8...
# 5   https://catalogue.cioos.ca/dataset/8d4296e0-7b...
# 6   https://catalogue.cioos.ca/dataset/ca-cioos_80...
# 7   https://catalogue.cioos.ca/dataset/fb1009b1-22...
# 8   https://catalogue.cioos.ca/dataset/ca-cioos_19...
# 9   https://catalogue.cioos.ca/dataset/ca-cioos_9c...
# 10  https://catalogue.cioos.ca/dataset/ca-cioos_89...
# 11  https://catalogue.cioos.ca/dataset/d75b491e-ad...
# 12  https://catalogue.cioos.ca/dataset/ca-cioos_89...
# 13  https://catalogue.cioos.ca/dataset/ca-cioos_93...
# 14  https://catalogue.cioos.ca/dataset/0fb1bc5e-0e...
# 15  https://catalogue.cioos.ca/dataset/ca-cioos_f8...
# 16  https://catalogue.cioos.ca/dataset/190f73aa-22...
# 17  https://catalogue.cioos.ca/dataset/ca-cioos_3b...
# 18  https://catalogue.cioos.ca/dataset/ca-cioos_6c...
# 19  https://catalogue.cioos.ca/dataset/ca-cioos_3b...
# 20  https://catalogue.cioos.ca/dataset/ca-cioos_67...
# 21  https://catalogue.cioos.ca/dataset/ca-cioos_e6...
# 22  https://catalogue.cioos.ca/dataset/ca-cioos_ca...
# 23  https://catalogue.cioos.ca/dataset/ca-cioos_9b...
# 24  https://catalogue.cioos.ca/dataset/ca-cioos_4a...
# 25  https://catalogue.cioos.ca/dataset/ca-cioos_b9...
# 26  https://catalogue.cioos.ca/dataset/ca-cioos_89...
# 27  https://catalogue.cioos.ca/dataset/147423a6-b1...
# 28  https://catalogue.cioos.ca/dataset/ca-cioos_31...
# 29  https://catalogue.cioos.ca/dataset/bfb56634-de...
# 30  https://catalogue.cioos.ca/dataset/ca-cioos_74...
# 31  https://catalogue.cioos.ca/dataset/e373c100-16...
# 32  https://catalogue.cioos.ca/dataset/ca-cioos_db...
# 33  https://catalogue.cioos.ca/dataset/4fd9173f-0e...
# 34  https://catalogue.cioos.ca/dataset/4d130096-1a...
# 35  https://catalogue.cioos.ca/dataset/30f103bd-6d...
# 36  https://catalogue.cioos.ca/dataset/ca-cioos_61...
# 37  https://catalogue.cioos.ca/dataset/e373c100-16...
# 38  https://catalogue.cioos.ca/dataset/ca-cioos_c0...
# 39  https://catalogue.cioos.ca/dataset/e373c100-16...
# 40  https://catalogue.cioos.ca/dataset/957e566c-8e...
# 41  https://catalogue.cioos.ca/dataset/ca-cioos_62...
# 42  https://catalogue.cioos.ca/dataset/ca-cioos_fe...
# 43  https://catalogue.cioos.ca/dataset/894eee8b-95...
# 44  https://catalogue.cioos.ca/dataset/ca-cioos_f8...
# 45  https://catalogue.cioos.ca/dataset/ca-cioos_b5...
# 46  https://catalogue.cioos.ca/dataset/ca-cioos_0e...
# 47  https://catalogue.cioos.ca/dataset/ca-cioos_22...
# 48  https://catalogue.cioos.ca/dataset/ca-cioos_96...
# 49  https://catalogue.cioos.ca/dataset/ca-cioos_22...
#
#                                                  name  \
# 0   Mise en ��uvre de la gestion communautaire des...
# 1   Tsawwassen - Duke Point Ferry Route Capteur d'...
# 2   Caract��risation biophysique de l'Anse du Port...
# 3   Multiparametric Decision Support Tool for the ...
# 4   Surfgrass Communities - Motile Invertebrate Su...
# 5   Atlantic Zone Monitoring Program : Review of O...
# 6   Enregistrement provisoire provisoire haute r��...
# 7                 Halifax Ocean Terminals��: Fairview
# 8   Infaunal invertebrates and contaminants in Sai...
# 9   Outil multiparam��trique d'aide �� la d��cisio...
# 10  Collecte int��gr��e de donn��es issues des exp...
# 11  Patricia Bay Conductivit��/Temp��rature/Profon...
# 12  Collecte int��gr��e de donn��es issues des exp...
# 13      GPS locations of Northern Gannets season 2014
# 14                        Halifax (Herring Cove) Buoy
# 15  Donn��es de chromatographie liquide �� haute p...
# 16  Cambridge Bay Conductivity Temperature Depth D...
# 17  Multiparametric Decision Support Tool for the ...
# 18  Hakai Institute Juvenile Salmon Program Time S...
# 19  Dynamique de l'��toile de mer et des macroinve...
# 20     Motile Invertebrate Surveys - BC Central Coast
# 21  Flow Cytometry data from the R/V TINRO, NOAA B...
# 22  Moored Acoustic Doppler Current Profiler (ADCP...
# 23  Donn��es du CTD de l'exp��dition 2019 de l'Ann...
# 24  High-resolution time series of surface seawate...
# 25  Results of annual surveys of the intertidal zo...
# 26  Integrated Data Collection from the Internatio...
# 27              NEGL, Rigolet, Nunatsiavut (NLQU0002)
# 28  Donn��es sur la biomasse des varechs sous la c...
# 29  Baynes Sound Carbon Dioxide Sensor Deployed 20...
# 30  Dissolved and particulate organic carbon chemi...
# 31                                   Fortune Bay Buoy
# 32  WISE-Man Project (WaterSat Imaging Spectromete...
# 33  Patricia Bay Capteur d'Oxyg��ne d��ploy�� 2013...
# 34         Bullseye Current Meter Deployed 2012-06-03
# 35  Strait of Georgia Central Conductivit��/Temp��...
# 36  Hakai Water Properties Vertical Profile Data M...
# 37                                 Bou��e Fortune Bay
# 38  Donn��es de qualit�� de l'eau du comt�� de She...
# 39                                   Fortune Bay Buoy
# 40  Endeavour South Current Meter Deployed 2012-06-14
# 41    Localisations GPS de fous de Bassan saison 2017
# 42  Enregistrement provisoire provisoire haute r��...
# 43  Yarrow Point Conductivity Temperature Depth De...
# 44  Inventaire d'abondance et estimation de la sup...
# 45  Carbone organique �� l'interface terre-oc��an ...
# 46  Biodiversit�� benthique en zone intertidale su...
# 47  Utilisation du marqueur MiFish (12S) pour le d...
# 48  Outil multiparam��trique d'aide �� la d��cisio...
# 49  Use of the MiFish Marker (12S) for the Develop...
#
#                                           description  \
# 0   Ce projet, qui est une initiative de P��ches e...
# 1   The Aanderaa Optode 3835 (S/N 418) was deploye...
# 2   L���anse-du-Portage dans la municipalit�� de N...
# 3   Data collected on lobsters in preseason fisher...
# 4   The surfgrass motile invertebrate dataset is a...
# 5   Des scientifiques de P��ches et Oc��ans Canada...
# 6   Cet ensemble de donn��es comprend des mesures ...
# 7   D��ploy��e en novembre 2015, la station m��t��...
# 8   Drs. Heather Hunt (University of New Brunswick...
# 9   Data collected on lobsters in preseason fisher...
# 10  Ce jeu de donn��es regroupe toutes les donn��e...
# 11  The Falmouth Scientific NXIC CTD 1622 was depl...
# 12  This dataset is a collection of all of the Int...
# 13  Depuis 2012, le [Laboratoire d'ornithologie ma...
# 14  Une bou��e m��t��orologique et oc��anographiqu...
# 15  Donn��es sur les pigments de chromatographie l...
# 16  The Sea-Bird SeaCAT SBE19plus V2 7589 was depl...
# 17  Egg development analysis data during the 2020 ...
# 18  The Hakai Institute Juvenile Salmon program is...
# 19  L'ensemble de donn��es sur la dynamique des as...
# 20  The motile invertebrate dataset is a component...
# 21  Phytoplankton community composition and size s...
# 22  This dataset contains measurements collected b...
# 23  CTD (conductivity, temperature, density) data ...
# 24  Cet ensemble de donn��es comprend des mesures ...
# 25  Each fall, around the high tides of the equino...
# 26  Ce jeu de donn��es regroupe toutes les donn��e...
# 27  NEGL - Rigolet, Nunatsiavut (NLQU0002). Les m�...
# 28  The understory kelp biomass dataset is a compo...
# 29  Ce Pro-Oceanus CO2-Pro CV (SN 40-718-75) a ��t...
# 30  This data package includes three datasets used...
# 31  Une bou��e m��t��orologique/oc��anographique d...
# 32  This dataset includes biogeochemical parameter...
# 33  The Alec Electronics Rinko-III 0014 was deploy...
# 34  The Nortek Aquadopp Current Meter 8407 was dep...
# 35  The Sea-Bird SeaCAT SBE19plus V2 7793 was depl...
# 36  Temperature, conductivity, dissolved oxygen, f...
# 37  Une bou��e m��t��orologique/oc��anographique d...
# 38  Le Center for Marine Applied Research (CMAR) m...
# 39  Une bou��e m��t��orologique/oc��anographique d...
# 40  Ce Nortek Aquadopp Current Meter A3L4889 AQD25...
# 41  Depuis 2012, le [Laboratoire d'ornithologie ma...
# 42  Cet ensemble de donn��es comprend des mesures ...
# 43  Ce Sea-Bird SeaCAT SBE19plus V2 6938 a ��t�� d...
# 44  La pr��sente ��tude a ��t�� r��alis��e dans le...
# 45  Cet ensemble de donn��es comprend trois ensemb...
# 46  Donn��es d'abondance de l'endofaune acquises e...
# 47  La caract��risation des esp��ces par l���ADN e...
# 48  Physico-chemical data collected on lobster fis...
# 49  La caract��risation des esp��ces par l���ADN e...
#
#                                              keywords
# 0                               gestion communautaire
# 1              volume_fraction_of_oxygen_in_sea_water
# 2                                  ��rosion c��ti��re
# 3                            habitat characterization
# 4                                               biota
# 5                              oceanographic missions
# 6                                 surface-measurement
# 7                                            humidity
# 8                                           s��diment
# 9                                     decision making
# 10  marineturtlesbirdsmammalsabundanceanddistribution
# 11                  sea_water_electrical_conductivity
# 12                                          nutrients
# 13                                 oiseaux migrateurs
# 14                                              dir19
# 15             biomasse-et-diversite-de-phytoplancton
# 16                              sea_water_sigma_theta
# 17                                resource management
# 18                                             salmon
# 19                                            wasting
# 20                                   species-tracking
# 21             biomasse-et-diversite-de-phytoplancton
# 22                               courants-sous-marins
# 23                                  particulatematter
# 24                           echange-ocean-atmosphere
# 25                               macrofaune benthique
# 26              abondance-et-distribution-de-poissons
# 27                                               gust
# 28                                              algae
# 29                                             Oceans
# 30                                             oceans
# 31                                          dew-point
# 32                                           nutrient
# 33                              Subsurfacetemperature
# 34                       northward_sea_water_velocity
# 35                        speed_of_sound_in_sea_water
# 36                                          turbidity
# 37                                               data
# 38                                     climate-change
# 39                                       currspd12avg
# 40                    sea_water_velocity_to_direction
# 41                        comportement d'alimentation
# 42                                mesures-en-continue
# 43                        speed_of_sound_in_sea_water
# 44                                               fish
# 45                                         rain-event
# 46                                              Autre
# 47  marineTurtlesBirdsMammalsAbundanceAndDistribution
# 48                              abundance and biomass
# 49                                               ADNe

# %%
# Convert the list of dictionaries into a pandas DataFrame
wiki_subset_50_random = pd.DataFrame(random_nodes)

# %%
# Display the DataFrame
print(wiki_subset_50_random)

# Save to a CSV file for visualization
# Save to a CSV file for visualization with proper comma separation
wiki_subset_50_random.to_csv('wiki_subset_50_random.csv', index=False)
# Out:
#                                               subject  \
# 0   https://catalogue.cioos.ca/dataset/ca-cioos_28...
# 1   https://catalogue.cioos.ca/dataset/ca-cioos_6c...
# 2   https://catalogue.cioos.ca/dataset/d549d183-e8...
# 3   https://catalogue.cioos.ca/dataset/33356c46-ef...
# 4   https://catalogue.cioos.ca/dataset/ca-cioos_96...
# ..                                                ...
# 95  https://catalogue.cioos.ca/dataset/e373c100-16...
# 96  https://catalogue.cioos.ca/dataset/ca-cioos_22...
# 97  https://catalogue.cioos.ca/dataset/ca-cioos_76...
# 98  https://catalogue.cioos.ca/dataset/ca-cioos_96...
# 99  https://catalogue.cioos.ca/dataset/ca-cioos_47...
#
#                                                  name  \
# 0   Nearshore Macrophyte Stable Isotopes - BC Cent...
# 1   Surface water CO2 parameters collected by Alas...
# 2   Barkley Canyon Axis  Capteur d'Oxyg��ne d��plo...
# 3   Strait of Georgia Central Acoustic Doppler Cur...
# 4   Multiparametric decision support tool for the ...
# ..                                                ...
# 95                                   Fortune Bay Buoy
# 96  Use of the MiFish Marker (12S) for the Develop...
# 97  Mesures de concentration de CO2 �� la surface ...
# 98  Multiparametric decision support tool for the ...
# 99  Nutriments de l'Institut Hakai (Dosser et al.,...
#
#                                           description                keywords  \
# 0   The macrophyte stable isotope dataset is a com...               nearshore
# 1   pCO2 and TCO2 measurements were made on surfac...                     sea
# 2   The Sea-Bird SBE 63 Dissolved Oxygen Sensor 63...   Subsurfacetemperature
# 3   Ce RDI Workhorse Quartermaster ADCP 150 kHz (S...   sea_water_temperature
# 4   Physico-chemical data collected on lobster fis...      suivi des esp��ces
# ..                                                ...                     ...
# 95  A 3 metre diameter meteorological/oceanographi...             currspd4avg
# 96  Species characterization by environmental DNA ...                    ADNe
# 97  Le chenal Kwakshua, situ�� pr��s du d��troit d...     salinite-de-surface
# 98  Donn��es physico-chimiques recueillies sur les...  d��veloppement durable
# 99  This repository contains the Hakai Institute n...       physical-chemical
#
#    creator
# 0
# 1
# 2
# 3
# 4
# ..     ...
# 95
# 96
# 97
# 98
# 99
#
# [100 rows x 5 columns]
